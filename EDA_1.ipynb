# %% [markdown]
# EDA for d3.js

# %%
import pandas as pd
video_game = pd.read_csv("./datasets/Video Game Sales with Ratings.csv")
print(video_game.shape)
video_game.head()
# Out:
# (16719, 16)
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
video_game["Critic_Count"]
# Out:
# 0        51.0
# 1         NaN
# 2        73.0
# 3        73.0
# 4         NaN
#          ...
# 16714     NaN
# 16715     NaN
# 16716     NaN
# 16717     NaN
# 16718     NaN
# Name: Critic_Count, Length: 16719, dtype: float64

# %%
video_game.dropna(inplace=True)
print(video_game.shape)
video_game.tail()
# Out:
# (6825, 16)
#                                     Name Platform  Year_of_Release     Genre  \
# 16667         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
#                           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16667                      NewKidCo      0.01      0.00       0.0
# 16677                  Midway Games      0.01      0.00       0.0
# 16696  Konami Digital Entertainment      0.00      0.01       0.0
# 16700                     Destineer      0.01      0.00       0.0
# 16706                       Unknown      0.00      0.01       0.0
#
#        Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 16667          0.0          0.01          46.0           4.0        2.4
# 16677          0.0          0.01          81.0          12.0        8.8
# 16696          0.0          0.01          80.0          20.0        7.6
# 16700          0.0          0.01          61.0          12.0        5.8
# 16706          0.0          0.01          60.0          12.0        7.2
#
#        User_Count           Developer Rating
# 16667        21.0       Fluid Studios      E
# 16677         9.0     Criterion Games      M
# 16696       412.0  Kojima Productions      M
# 16700        43.0        Atomic Games      T
# 16706        13.0              SimBin   E10+

# %% [markdown]
# ## 圆图

# %%
sales_counts = video_game["Global_Sales"].value_counts().sort_values(ascending=True)

# 获取排名前十的 Global_Sales 的名称列表
top_50_sales = list(sales_counts.head(50).index)

sales_topdf = video_game[video_game['Global_Sales'].isin(top_50_sales)]
sales_topdf = sales_topdf.reset_index(drop=True)


sales_topdf.head()
# Out:
#                         Name Platform  Year_of_Release     Genre Publisher  \
# 0          Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 1                   Wii Play      Wii           2006.0      Misc  Nintendo
# 2  New Super Mario Bros. Wii      Wii           2009.0  Platform  Nintendo
# 3              Mario Kart DS       DS           2005.0    Racing  Nintendo
# 4                    Wii Fit      Wii           2007.0    Sports  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     15.61     10.93      3.28         2.95         32.77          80.0
# 1     13.96      9.18      2.93         2.84         28.92          58.0
# 2     14.44      6.94      4.70         2.24         28.32          87.0
# 3      9.71      7.47      4.13         1.90         23.21          91.0
# 4      8.92      8.03      3.60         2.15         22.70          80.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          73.0          8       192.0  Nintendo      E
# 1          41.0        6.6       129.0  Nintendo      E
# 2          80.0        8.4       594.0  Nintendo      E
# 3          64.0        8.6       464.0  Nintendo      E
# 4          63.0        7.7       146.0  Nintendo      E

# %%
sales_topdf["Critic_Score"]=sales_topdf["Critic_Score"]/10
sales_topdf["Critic_Score"]
# Out:
# 0     8.0
# 1     5.8
# 2     8.7
# 3     9.1
# 4     8.0
# 5     6.1
# 6     8.0
# 7     9.7
# 8     9.5
# 9     7.7
# 10    9.7
# 11    9.5
# 12    7.7
# 13    9.5
# 14    8.8
# 15    8.7
# 16    8.3
# 17    8.3
# 18    9.4
# 19    8.8
# 20    9.7
# 21    9.3
# 22    8.8
# 23    8.6
# 24    9.8
# 25    9.6
# 26    9.0
# 27    8.4
# 28    9.4
# 29    9.8
# 30    7.3
# 31    7.4
# 32    7.8
# 33    9.1
# 34    9.2
# 35    8.7
# 36    9.3
# 37    7.4
# 38    7.1
# 39    9.4
# 40    8.8
# 41    7.2
# 42    9.6
# 43    8.2
# 44    9.5
# 45    6.8
# 46    8.8
# 47    9.7
# 48    9.3
# 49    7.5
# Name: Critic_Score, dtype: float64

# %%
sales_topdf.to_csv("sales_topdf.csv")

# %% [markdown]
# ## top publisher

# %%
# 对 publisher 列进行统计并排序
publisher_counts = video_game["Publisher"].value_counts().sort_values(ascending=False)

# 获取排名前十的 publisher 的名称列表
top_8_publishers = list(publisher_counts.head(8).index)

print(top_8_publishers)
# Out:
# ['Electronic Arts', 'Ubisoft', 'Activision', 'Sony Computer Entertainment', 'THQ', 'Nintendo', 'Sega', 'Take-Two Interactive']

# %%
# 筛选出在前8列表中的行
video_game = video_game[video_game['Publisher'].isin(top_8_publishers)]
print(video_game.shape)
# Out:
# (3403, 16)

# %% [markdown]
# ## developer top8

# %%
developer_counts = video_game["Developer"].value_counts().sort_values(ascending=False)
top_8_developer = list(developer_counts.head(8).index)

print(top_8_developer)
# Out:
# ['EA Canada', 'EA Sports', 'Ubisoft', 'Ubisoft Montreal', 'EA Tiburon', 'Nintendo', 'Electronic Arts', 'Visual Concepts']

# %%
video_game = video_game[video_game['Developer'].isin(top_8_developer)]
print(video_game.shape)
# Out:
# (763, 16)

# %% [markdown]
# ## platform top8

# %%
platform_counts = video_game["Platform"].value_counts().sort_values(ascending=False)
top_8_platform = list(platform_counts.head(8).index)
print(top_8_platform)
# Out:
# ['X360', 'PS2', 'PS3', 'XB', 'GC', 'Wii', 'PC', 'PSP']

# %%
video_game = video_game[video_game['Platform'].isin(top_8_platform)]
print(video_game.shape)
# Out:
# (606, 16)

# %% [markdown]
# ## genre

# %%
video_game = pd.DataFrame(video_game)
video_game = video_game.reset_index(drop=True)
video_game.head()
# Out:
#                         Name Platform  Year_of_Release     Genre Publisher  \
# 0                 Wii Sports      Wii           2006.0    Sports  Nintendo
# 1             Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 2          Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 3                   Wii Play      Wii           2006.0      Misc  Nintendo
# 4  New Super Mario Bros. Wii      Wii           2009.0  Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     15.68     12.76      3.79         3.29         35.52          82.0
# 2     15.61     10.93      3.28         2.95         32.77          80.0
# 3     13.96      9.18      2.93         2.84         28.92          58.0
# 4     14.44      6.94      4.70         2.24         28.32          87.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1          73.0        8.3       709.0  Nintendo      E
# 2          73.0          8       192.0  Nintendo      E
# 3          41.0        6.6       129.0  Nintendo      E
# 4          80.0        8.4       594.0  Nintendo      E

# %%
video_game['Category'] = 'Others'
for i in range(len(video_game)):
    if video_game['Genre'][i] == 'Shooter' or video_game['Genre'][i] == 'Action':
        video_game['Category'][i] = 'Action'
    elif video_game['Genre'][i] == 'Simulation' or video_game['Genre'][i] == 'Strategy' or video_game['Genre'][i] == 'Role-Playing':
        video_game['Category'][i] = 'Strategy'
    elif video_game['Genre'][i] == 'Puzzle' or video_game['Genre'][i] == 'Misc':
        video_game['Category'][i] = 'Puzzle'
    elif video_game['Genre'][i] == 'Sports' or video_game['Genre'][i] == 'Racing' or video_game['Genre'][i] == 'Fighting':
        video_game['Category'][i] = 'Sports'
    elif video_game['Genre'][i] == 'Adventure' or video_game['Genre'][i] == 'Platform':
        video_game['Category'][i] = 'Adventure'

video_game.head()
# Out:
# /var/folders/dv/x_66hhts063355xh4tw6jl6w0000gn/T/ipykernel_2111/1039966122.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/dv/x_66hhts063355xh4tw6jl6w0000gn/T/ipykernel_2111/1039966122.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/dv/x_66hhts063355xh4tw6jl6w0000gn/T/ipykernel_2111/1039966122.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/dv/x_66hhts063355xh4tw6jl6w0000gn/T/ipykernel_2111/1039966122.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/dv/x_66hhts063355xh4tw6jl6w0000gn/T/ipykernel_2111/1039966122.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                         Name Platform  Year_of_Release     Genre Publisher  \
# 0                 Wii Sports      Wii           2006.0    Sports  Nintendo
# 1             Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 2          Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 3                   Wii Play      Wii           2006.0      Misc  Nintendo
# 4  New Super Mario Bros. Wii      Wii           2009.0  Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     15.68     12.76      3.79         3.29         35.52          82.0
# 2     15.61     10.93      3.28         2.95         32.77          80.0
# 3     13.96      9.18      2.93         2.84         28.92          58.0
# 4     14.44      6.94      4.70         2.24         28.32          87.0
#
#    Critic_Count User_Score  User_Count Developer Rating   Category
# 0          51.0          8       322.0  Nintendo      E     Sports
# 1          73.0        8.3       709.0  Nintendo      E     Sports
# 2          73.0          8       192.0  Nintendo      E     Sports
# 3          41.0        6.6       129.0  Nintendo      E     Puzzle
# 4          80.0        8.4       594.0  Nintendo      E  Adventure

# %%
video_game.shape
# Out:
# (606, 17)

# %%
video_game.head()
# Out:
#                         Name Platform  Year_of_Release     Genre Publisher  \
# 0                 Wii Sports      Wii           2006.0    Sports  Nintendo
# 1             Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 2          Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 3                   Wii Play      Wii           2006.0      Misc  Nintendo
# 4  New Super Mario Bros. Wii      Wii           2009.0  Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     15.68     12.76      3.79         3.29         35.52          82.0
# 2     15.61     10.93      3.28         2.95         32.77          80.0
# 3     13.96      9.18      2.93         2.84         28.92          58.0
# 4     14.44      6.94      4.70         2.24         28.32          87.0
#
#    Critic_Count User_Score  User_Count Developer Rating   Category
# 0          51.0          8       322.0  Nintendo      E     Sports
# 1          73.0        8.3       709.0  Nintendo      E     Sports
# 2          73.0          8       192.0  Nintendo      E     Sports
# 3          41.0        6.6       129.0  Nintendo      E     Puzzle
# 4          80.0        8.4       594.0  Nintendo      E  Adventure

# %%
video_game.to_csv("cleaned_video_game.csv")

# %%
df=pd.read_csv('/Users/xiangxin/2023-anly503-xx123/ANLY503_FINAL_PROJECT/cleaned_video_game.csv')
df
# Out:
#       Unnamed: 0 Platform    Genre                    Publisher  Critic_Score  \
# 0              0      PS2   Racing  Sony Computer Entertainment          95.0
# 1              1     X360  Shooter                   Activision          88.0
# 2              2     X360  Shooter                   Activision          87.0
# 3              3      PS3  Shooter                   Activision          83.0
# 4              4     X360  Shooter                   Activision          83.0
# ...          ...      ...      ...                          ...           ...
# 1553        1553      PS2  Shooter                   Activision          70.0
# 1554        1554       PC   Action                      Ubisoft          79.0
# 1555        1555       PC   Racing                          THQ          61.0
# 1556        1556       PC   Action                   Activision          58.0
# 1557        1557       PC   Action                   Activision          78.0
#
#       User_Score Rating     Cat
# 0            8.4      E  Sports
# 1            3.4      M  Action
# 2            6.3      M  Action
# 3            5.3      M  Action
# 4            4.8      M  Action
# ...          ...    ...     ...
# 1553         9.2   E10+  Action
# 1554         6.8      E  Action
# 1555         5.0      T  Sports
# 1556         8.0   E10+  Action
# 1557         7.9      T  Action
#
# [1558 rows x 8 columns]

# %% [markdown]
# ## steam data eda

# %%
steam_df = pd.read_csv("./datasets/steam.csv")
mask = ~steam_df['genres'].str.contains(';')
mask
# Apply the mask to the DataFrame to keep only the rows where 'genres' does not contain ';'
steam_df = steam_df[mask]

# %%
print(steam_df.shape)
steam_df.head()
# Out:
# (4043, 18)
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike   2000-11-01        1             Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1        Action;FPS;Multiplayer             0              3318
# 2  FPS;World War II;Multiplayer             0              3416
# 3        Action;FPS;Multiplayer             0              1273
# 4             FPS;Action;Sci-fi             0              5250
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
# 3               267               258              184   5000000-10000000
# 4               288               624              415   5000000-10000000
#
#    price
# 0   7.19
# 1   3.99
# 2   3.99
# 3   3.99
# 4   3.99

# %% [markdown]
# ## top 8 genres

# %%
ge_counts = steam_df["genres"].value_counts().sort_values(ascending=False)
top_10_ge = list(ge_counts.head(10).index)
print(top_10_ge)
# Out:
# ['Action', 'Indie', 'Casual', 'Adventure', 'Strategy', 'Simulation', 'RPG', 'Racing', 'Sports', 'Utilities']

# %%
steam_df = steam_df[steam_df['genres'].isin(top_10_ge)]
steam_df = steam_df.reset_index(drop=True)
print(steam_df.shape)
steam_df.head()
# Out:
# (3973, 19)
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike   2000-11-01        1             Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1        Action;FPS;Multiplayer             0              3318
# 2  FPS;World War II;Multiplayer             0              3416
# 3        Action;FPS;Multiplayer             0              1273
# 4             FPS;Action;Sci-fi             0              5250
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
# 3               267               258              184   5000000-10000000
# 4               288               624              415   5000000-10000000
#
#    price   price_range
# 0   7.19  1-20 dollars
# 1   3.99  1-20 dollars
# 2   3.99  1-20 dollars
# 3   3.99  1-20 dollars
# 4   3.99  1-20 dollars

# %%
steam_df["price_range"]="na"
for i in range(len(steam_df)):
    if steam_df['price'][i] == 0 :
        steam_df['price_range'][i] = 'free'
    elif steam_df['price'][i] >0 and steam_df['price'][i]<=20:
        steam_df['price_range'][i] = '1-20 dollars'
    elif steam_df['price'][i] >20 and steam_df['price'][i]<=50:
        steam_df['price_range'][i] = '20-50 dollars'
    elif steam_df['price'][i] >50 and steam_df['price'][i]<=500:
        steam_df['price_range'][i] = '50-500 dollars'

steam_df.head()
# Out:
# /var/folders/dv/x_66hhts063355xh4tw6jl6w0000gn/T/ipykernel_2111/1591395118.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/dv/x_66hhts063355xh4tw6jl6w0000gn/T/ipykernel_2111/1591395118.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/anly503/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/miniforge3/envs/anly503/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniforge3/envs/anly503/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 19
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[188], line 3
#       1 steam_df["price_range"]="na"
#       2 for i in range(len(steam_df)):
# ----> 3     if steam_df['price'][i] == 0 :
#       4         steam_df['price_range'][i] = 'free'
#       5     elif steam_df['price'][i] >0 and steam_df['price'][i]<=20:
#
# File ~/miniforge3/envs/anly503/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/miniforge3/envs/anly503/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/miniforge3/envs/anly503/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 19

# %%
steam_df.to_csv("steam_df.csv")

# %%
print(steam_df["price_range"])
# Out:
# 0        1-20 dollars
# 1        1-20 dollars
# 2        1-20 dollars
# 3        1-20 dollars
# 4        1-20 dollars
#              ...
# 27037              na
# 27040              na
# 27047              na
# 27061              na
# 27069              na
# Name: price_range, Length: 4043, dtype: object
